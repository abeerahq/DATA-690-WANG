# %% [markdown]
# # Assignment 2
#
# **Author**: Abeerah Qadir
#
# **Date**: February 7, 2021

# %% [markdown]
# #### Prompts a user to enter 10 integers
#
# ##### (Detects if user makes a mistake)

# %%
user_inputs=[] # Create an empty list.
for i in range(1, 11): # Specify a range.
    while True:
        try:
            user_input=int(input("Please enter an integer")) # Numeric integer is returned.
            break
        except ValueError: # Value Error allows user to retry if string is entered.
            print("Sorry you must enter a number!")
            continue
    print(f"You have entered #{i}:", user_input)
    user_inputs.append(user_input) 
    # All values entered are now put into the empty list created in the first step.
print(user_inputs) #Displays all 10 inputs.
# Out:
# You have entered #1: 12
# You have entered #2: 32
# You have entered #3: 46
# You have entered #4: 58
# You have entered #5: 54
# You have entered #6: 53
# You have entered #7: 20
# You have entered #8: 7
# You have entered #9: 22
# You have entered #10: 21
# [12, 32, 46, 58, 54, 53, 20, 7, 22, 21]

# %% [markdown]
# #### Minimum Value

# %%
min(user_inputs)
# Out:
# 7

# %% [markdown]
# #### Maximum Value

# %%
max(user_inputs)
# Out:
# 58

# %% [markdown]
# #### Range

# %%
range = (max(user_inputs)-min(user_inputs))
print(range)
# Out:
# 51

# %% [markdown]
# #### Mean

# %%
n = len(user_inputs)
user_inputs = sum(user_inputs) 
mean = user_inputs / n 
print("Mean / Average is: " + str(mean))
# Out:
# Mean / Average is: 32.5

# %% [markdown]
# #### Variance

# %%
data = [12, 32, 46, 58, 54, 53, 20, 7, 22, 21]
avg = sum(data) / len(data)
var = sum((x-avg)**2 for x in data) / len(data)
print(var)
# Out:
# 318.45

# %% [markdown]
# #### Standard Deviation

# %%
data = [12, 32, 46, 58, 54, 53, 20, 7, 22, 21]
avg = sum(data) / len(data)
var = sum((x-avg)**2 for x in data) / len(data)
std = var**0.5
print(std)
# Out:
# 17.845167413056117

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7457a011-51f4-47c1-9803-70c58174b4ce' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
