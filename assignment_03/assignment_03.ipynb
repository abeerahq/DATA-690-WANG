# %% [markdown]
# ## Assignment 3
#
# **Author**: Abeerah Qadir
#
# **Date**: February 14, 2021

# %% [markdown]
# ### 100 random integers between 0 and 9

# %% [markdown]
# #### 10 by 10 matrix

# %%
import random 

def make_board(row_num=10):
    board = []

    for rows in range(row_num):
        rows = []
        
        for elements in range(row_num):
            element = random.randint(0, 9)
            print(element, end = " ")
            
            rows.append(element)

        print("")
        board.append(rows)

    

make_board(10)
# Out:
# 7 4 3 1 7 0 7 3 0 2
# 9 7 8 2 8 9 7 7 4 1
# 4 8 1 3 4 2 1 3 0 6
# 4 4 1 1 3 4 1 8 8 6
# 4 6 6 1 2 2 8 1 2 3
# 6 7 6 6 3 0 5 1 2 8
# 2 8 5 9 9 5 7 0 8 4
# 7 5 8 5 9 2 2 8 3 2
# 4 6 3 4 2 2 6 1 9 0
# 4 0 8 8 3 6 3 4 2 6

# %% [markdown]
# #### Print "@" to replace odd numbers

# %%
import random #random number import

def make_board(row_num=10):
    board = []

    for board_row in range(row_num):
        rows = []

        for elements in range(row_num):
            element = random.randint(0, 9) #Randomly generates a number
            
            if element % 2 == 1:
                element = '@'
            rows.append(element)

            print(element,end = " ")
        
        board.append(rows)
        print("")
    

make_board()
# Out:
# 0 0 @ @ @ 2 @ @ @ @
# 8 8 0 @ @ 8 @ @ @ 2
# 2 2 4 8 4 @ 0 @ @ 4
# 6 @ @ 8 @ 2 @ @ @ @
# @ 2 2 @ @ @ @ 4 6 @
# @ @ @ @ @ @ @ 8 8 @
# 4 @ 0 @ @ @ @ @ 2 6
# @ @ 8 @ @ @ @ 2 6 @
# @ @ 4 @ 0 @ @ @ 8 6
# @ @ @ @ @ @ @ @ 4 4

# %% [markdown]
# #### Use "*" to separate the total from the numbers

# %%
import random #random number import

def make_board(row_num=10, board_return='on'):
    board = []
    
    for board_rows in range(row_num):
        rows = []
        row_sum = 0

        for elements in range(row_num):
            elements = random.randint(0, 9) #Randomly generates a number between 0 and 9
            
            if elements % 2 == 1:
                c = '@'
                
            rows.append(elements)

            try:
                row_sum+=elements 
            except:
                row_sum+=0 #Keep any changed '@' as 0 
            print(elements,end=" ")


        rows.append(f"* {row_sum}")
        print(f"* {row_sum}")
        board.append(rows)  

    if board_return == 'on':
        return(board)

make_board(10,'off')
# Out:
# 4 9 9 2 5 5 9 7 9 0 * 59
# 2 3 9 5 7 5 4 8 6 3 * 52
# 1 2 2 3 0 3 3 4 5 7 * 30
# 1 1 0 0 8 2 4 5 2 0 * 23
# 1 6 1 9 3 6 1 0 6 1 * 34
# 1 6 6 7 0 7 3 1 7 1 * 39
# 2 5 9 5 2 7 3 0 7 4 * 44
# 8 5 7 9 8 9 1 6 4 1 * 58
# 9 5 7 8 1 3 9 0 4 2 * 48
# 4 9 6 2 4 1 4 8 9 6 * 53

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0cda7c1b-1fc2-4960-a223-0c0e1ccc4fc6' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
